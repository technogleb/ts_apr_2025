# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.api import VAR

# %% [markdown]
# ## Random series

# %%
s1 = np.random.normal(0, 1, 100)
s2 = np.random.normal(0, 1, 100)

# %%
df = pd.DataFrame({'s1': s1, 's2': s2})

# %%
pd.Series(s1).plot()
# Out:
# <Axes: >

# %%
var = VAR(df)

# %%
res = var.fit(maxlags=30)

# %%
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 23, Apr, 2025
# Time:                     23:23:14
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    2.36068
# Nobs:                     70.0000    HQIC:               -0.00152856
# Log likelihood:          -22.1170    FPE:                    1.36630
# AIC:                     -1.55813    Det(Omega_mle):        0.390121
# --------------------------------------------------------------------
# Results for equation s1
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const         -0.467579         0.325758           -1.435           0.151
# L1.s1         -0.046203         0.326067           -0.142           0.887
# L1.s2          0.203545         0.324431            0.627           0.530
# L2.s1         -0.472858         0.304615           -1.552           0.121
# L2.s2          0.396379         0.347234            1.142           0.254
# L3.s1         -0.263411         0.348692           -0.755           0.450
# L3.s2         -0.192584         0.349722           -0.551           0.582
# L4.s1          0.247768         0.366069            0.677           0.499
# L4.s2         -0.632795         0.290309           -2.180           0.029
# L5.s1         -0.213773         0.289235           -0.739           0.460
# L5.s2         -0.060843         0.315481           -0.193           0.847
# L6.s1         -0.191096         0.269469           -0.709           0.478
# L6.s2         -0.395606         0.293140           -1.350           0.177
# L7.s1         -0.326437         0.214047           -1.525           0.127
# L7.s2         -0.121077         0.352140           -0.344           0.731
# L8.s1         -0.179582         0.237663           -0.756           0.450
# L8.s2         -0.051929         0.364242           -0.143           0.887
# L9.s1         -0.118083         0.270732           -0.436           0.663
# L9.s2          0.420747         0.367243            1.146           0.252
# L10.s1        -0.117861         0.273791           -0.430           0.667
# L10.s2         0.393532         0.394571            0.997           0.319
# L11.s1         0.448537         0.272674            1.645           0.100
# L11.s2         0.558961         0.370004            1.511           0.131
# L12.s1         0.164457         0.278574            0.590           0.555
# L12.s2         0.434468         0.385902            1.126           0.260
# L13.s1         0.095741         0.276651            0.346           0.729
# L13.s2        -0.130020         0.406980           -0.319           0.749
# L14.s1         0.262466         0.314019            0.836           0.403
# L14.s2         1.015301         0.384600            2.640           0.008
# L15.s1        -0.428807         0.332609           -1.289           0.197
# L15.s2         0.424415         0.460507            0.922           0.357
# L16.s1        -0.207641         0.284809           -0.729           0.466
# L16.s2         0.347156         0.420931            0.825           0.410
# L17.s1        -0.232446         0.253736           -0.916           0.360
# L17.s2         0.200479         0.373649            0.537           0.592
# L18.s1         0.027385         0.274223            0.100           0.920
# L18.s2         0.083603         0.379726            0.220           0.826
# L19.s1        -0.018975         0.274573           -0.069           0.945
# L19.s2         0.532188         0.398293            1.336           0.181
# L20.s1         0.094489         0.266217            0.355           0.723
# L20.s2         0.270982         0.428142            0.633           0.527
# L21.s1         0.091829         0.265336            0.346           0.729
# L21.s2         0.549003         0.336119            1.633           0.102
# L18.s1         0.069899         0.226399            0.309           0.758
# L18.s2        -0.295615         0.313502           -0.943           0.346
# L19.s1         0.043772         0.226688            0.193           0.847
# L19.s2        -0.327137         0.328831           -0.995           0.320
# L20.s1        -0.290239         0.219789           -1.321           0.187
# L20.s2         0.229021         0.353475            0.648           0.517
# L21.s1        -0.238915         0.219062           -1.091           0.275
# L21.s2         0.304116         0.277501            1.096           0.273
# L22.s1        -0.056924         0.210735           -0.270           0.787
# L22.s2        -0.326494         0.285322           -1.144           0.252
# L23.s1         0.259974         0.225398            1.153           0.249
# L23.s2        -0.454050         0.302485           -1.501           0.133
# L24.s1         0.106683         0.241280            0.442           0.658
# L24.s2         0.040866         0.327065            0.125           0.901
# L25.s1         0.338185         0.320515            1.055           0.291
# L25.s2         0.070807         0.323438            0.219           0.827
# L26.s1        -0.495008         0.327354           -1.512           0.130
# L26.s2        -0.148428         0.254379           -0.583           0.560
# L27.s1         0.337980         0.289494            1.167           0.243
# L27.s2         0.099352         0.263389            0.377           0.706
# L28.s1        -0.131239         0.348977           -0.376           0.707
# L28.s2         0.390296         0.266912            1.462           0.144
# L29.s1        -0.067694         0.294795           -0.230           0.818
# L29.s2         0.315637         0.269057            1.173           0.241
# L30.s1        -0.073068         0.265559           -0.275           0.783
# L30.s2        -0.191365         0.215058           -0.890           0.374
# =========================================================================
#
# Correlation matrix of residuals
#             s1        s2
# s1    1.000000 -0.035145
# s2   -0.035145  1.000000

# %%
df_pred = res.forecast(df.values, 10)

# %%
pd.DataFrame(df_pred).plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Not random series

# %%
df = pd.read_csv('../data/stability_index.csv')

# %%
df.plot(figsize=(20, 10))
# Out:
# <Axes: >

# %%
df = df[['3', '2']]

# %%
df.plot(figsize=(10, 5))
# Out:
# <Axes: >

# %%
df.fillna(0, axis=0, inplace=True)
# Out:
# /var/folders/xk/304zh5617yn50x0ys84shn5m0000gn/T/ipykernel_51850/1496159409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0, axis=0, inplace=True)

# %%
var = VAR(df)

# %%
res = var.fit()

# %%
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 23, Apr, 2025
# Time:                     23:25:30
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    12.6549
# Nobs:                     4144.00    HQIC:                   12.6489
# Log likelihood:          -37956.0    FPE:                    310423.
# AIC:                      12.6457    Det(Omega_mle):         309974.
# --------------------------------------------------------------------
# Results for equation 3
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const        10.726788         0.639865           16.764           0.000
# L1.3          0.475652         0.026454           17.980           0.000
# L1.2          0.195957         0.017492           11.203           0.000
# ========================================================================
#
# Results for equation 2
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const        16.084601         0.944568           17.029           0.000
# L1.3          0.011404         0.039052            0.292           0.770
# L1.2          0.764389         0.025822           29.603           0.000
# ========================================================================
#
# Correlation matrix of residuals
#             3         2
# 3    1.000000  0.856721
# 2    0.856721  1.000000

# %%
pd.Series(res.forecast(df.values, 120)[:, 0]).plot()
# Out:
# <Axes: >
